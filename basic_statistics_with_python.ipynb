# %%
from IPython.core.interactiveshell import prefilter
import pandas as pd
import numpy as np
import scipy.stats
import statistics
import matplotlib.pyplot as prefilter

data = pd.read_table(r"/content/sample_data/Data3.txt")
data.head()
# Out:
#      X1     X2      Y    IQ     T  Sex    R
# 0  16.0  18.25  17.96  83.0  52.0  1.0  1.0
# 1   9.5  11.00  10.00  64.0  39.0  1.0  1.0
# 2  19.0  18.50  17.82  83.0  58.0  1.0  1.0
# 3  19.0  18.00  18.79  79.0  58.0  1.0  1.0
# 4  15.5  18.25  18.43  94.0  51.0  1.0  1.0

# %%
pd.read_table("Data3.txt")

# %%
data[data.columns[[2,3]]]
# Out:
#         Y    IQ
# 0   17.96  83.0
# 1   10.00  64.0
# 2   17.82  83.0
# 3   18.79  79.0
# 4   18.43  94.0
# 5   14.96  71.0
# 6   15.19  73.0
# 7   15.79  73.0
# 8   16.71  79.0
# 9   16.45  72.0
# 10  14.36  56.0
# 11  12.76  53.0
# 12  17.98  76.0
# 13  18.92  88.0
# 14  19.35  93.0
# 15  11.64  62.0
# 16  17.39  85.0
# 17  14.99  69.0
# 18  15.41  76.0
# 19  18.24  88.0
# 20  17.64  78.0
# 21  13.46  74.0
# 22  18.34  88.0
# 23  20.00  91.0
# 24  14.39  73.0
# 25  17.94  81.0
# 26  11.49  59.0
# 27  17.36  82.0
# 28  19.23  91.0
# 29  12.84  62.0
# 30  18.46  86.0
# 31  18.49  87.0
# 32  17.36  81.0
# 33  16.75  81.0
